# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Products & Sales Data.csv")

# %% [markdown]
# # First five datapoints

# %%
data.head()
# Out:
#    Sales ID Product Category              Product Name  Product Quantity  \
# 0       NaN              NaN                       NaN               NaN
# 1       NaN              NaN                       NaN               NaN
# 2    1151.0     Refrigerator           Dawlance 547-WB               4.0
# 3       NaN     Refrigerator  Haier Single Door HDF-24               3.0
# 4       NaN              NaN                       NaN               NaN
#
#    Product Salescost Date Of Sales  Total Amount
# 0                NaN           NaN           NaN
# 1                NaN           NaN           NaN
# 2            70000.0      7/1/2021      505000.0
# 3            75000.0           NaN           NaN
# 4                NaN           NaN           NaN

# %%
# Some basic information regarding data its value as well as its type. 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sales ID           149 non-null    float64
#  1   Product Category   320 non-null    object
#  2   Product Name       320 non-null    object
#  3   Product Quantity   320 non-null    float64
#  4   Product Salescost  320 non-null    float64
#  5   Date Of Sales      149 non-null    object
#  6   Total Amount       148 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 26.1+ KB

# %%
data.dtypes
# Out:
# Sales ID             float64
# Product Category      object
# Product Name          object
# Product Quantity     float64
# Product Salescost    float64
# Date Of Sales         object
# Total Amount         float64
# dtype: object

# %%
data['Date']=pd.to_datetime(data['Date Of Sales'])

# %%
data.dtypes
# Out:
# Sales ID                    float64
# Product Category             object
# Product Name                 object
# Product Quantity            float64
# Product Salescost           float64
# Date Of Sales                object
# Total Amount                float64
# Date                 datetime64[ns]
# dtype: object

# %%
data.isnull().sum()
# Out:
# Sales ID             326
# Product Category     155
# Product Name         155
# Product Quantity     155
# Product Salescost    155
# Date Of Sales        326
# Total Amount         327
# Date                 326
# dtype: int64

# %%
data.iloc[0]
# Out:
# Sales ID             NaN
# Product Category     NaN
# Product Name         NaN
# Product Quantity     NaN
# Product Salescost    NaN
# Date Of Sales        NaN
# Total Amount         NaN
# Date                 NaT
# Name: 0, dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=475, step=1)

# %%
data=data.set_index("Date")

# %%
data.head()
# Out:
#             Sales ID Product Category              Product Name  \
# Date
# NaT              NaN              NaN                       NaN
# NaT              NaN              NaN                       NaN
# 2021-07-01    1151.0     Refrigerator           Dawlance 547-WB
# NaT              NaN     Refrigerator  Haier Single Door HDF-24
# NaT              NaN              NaN                       NaN
#
#             Product Quantity  Product Salescost Date Of Sales  Total Amount
# Date
# NaT                      NaN                NaN           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
# 2021-07-01               4.0            70000.0      7/1/2021      505000.0
# NaT                      3.0            75000.0           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN

# %%
sns.set(rc={'figure.figsize':(20,8)})
data['Product Salescost'].plot(linewidth=0.8)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.set(rc={'figure.figsize':(20,8)})
data['Total Amount'].plot(linewidth=0.8)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cols_plot=['Total Amount','Product Salescost']
axes = data[cols_plot].plot(marker='.', alpha=0.8, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('Date')

# %%
data.head()
# Out:
#             Sales ID Product Category              Product Name  \
# Date
# NaT              NaN              NaN                       NaN
# NaT              NaN              NaN                       NaN
# 2021-07-01    1151.0     Refrigerator           Dawlance 547-WB
# NaT              NaN     Refrigerator  Haier Single Door HDF-24
# NaT              NaN              NaN                       NaN
#
#             Product Quantity  Product Salescost Date Of Sales  Total Amount
# Date
# NaT                      NaN                NaN           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
# 2021-07-01               4.0            70000.0      7/1/2021      505000.0
# NaT                      3.0            75000.0           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN

# %%
data['Year']=data.index.year

# %%
data.tail()
# Out:
#             Sales ID Product Category                  Product Name  \
# Date
# NaT              NaN              NaN                           NaN
# 2021-12-24    1299.0               Tv            Sony Z9J BRAVIA XR
# NaT              NaN              NaN                           NaN
# 2021-12-29    1300.0               Tv   EcoStar LED HD Frameless TV
# NaT              NaN     Refrigerator  Hitachi Double Glass Door FP
#
#             Product Quantity  Product Salescost Date Of Sales  Total Amount  \
# Date
# NaT                      NaN                NaN           NaN           NaN
# 2021-12-24              20.0            97000.0    12/24/2021     1940000.0
# NaT                      NaN                NaN           NaN           NaN
# 2021-12-29              15.0            74000.0    12/29/2021     1650000.0
# NaT                      5.0           108000.0           NaN           NaN
#
#               Year
# Date
# NaT            NaN
# 2021-12-24  2021.0
# ...

# %%
data['Month']=data.index.month

# %%
data.head()
# Out:
#             Sales ID Product Category              Product Name  \
# Date
# NaT              NaN              NaN                       NaN
# NaT              NaN              NaN                       NaN
# 2021-07-01    1151.0     Refrigerator           Dawlance 547-WB
# NaT              NaN     Refrigerator  Haier Single Door HDF-24
# NaT              NaN              NaN                       NaN
#
#             Product Quantity  Product Salescost Date Of Sales  Total Amount  \
# Date
# NaT                      NaN                NaN           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
# 2021-07-01               4.0            70000.0      7/1/2021      505000.0
# NaT                      3.0            75000.0           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
#
#               Year  Month
# Date
# NaT            NaN    NaN
# NaT            NaN    NaN
# ...

# %%
data['weekDay']=data.index.day_name()

# %%
data.head()
# Out:
#             Sales ID Product Category              Product Name  \
# Date
# NaT              NaN              NaN                       NaN
# NaT              NaN              NaN                       NaN
# 2021-07-01    1151.0     Refrigerator           Dawlance 547-WB
# NaT              NaN     Refrigerator  Haier Single Door HDF-24
# NaT              NaN              NaN                       NaN
#
#             Product Quantity  Product Salescost Date Of Sales  Total Amount  \
# Date
# NaT                      NaN                NaN           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
# 2021-07-01               4.0            70000.0      7/1/2021      505000.0
# NaT                      3.0            75000.0           NaN           NaN
# NaT                      NaN                NaN           NaN           NaN
#
#               Year  Month   weekDay
# Date
# NaT            NaN    NaN       NaN
# ...

# %%
sns.boxplot(data=data, x='weekDay', y='Total Amount');

# %%
sns.boxplot(data=data, x='weekDay', y='Product Salescost');

# %%
sns.boxplot(data=data, x='Month', y='Product Salescost');

# %%
sns.boxplot(data=data, x='Month', y='Total Amount');

# %%
sns.boxplot(data=data, x='Year', y='Product Salescost');

# %%
#for Predication.

# %%
data2 = data.iloc[:,4]

# %%
data2.head()
# Out:
# Date
# NaT               NaN
# NaT               NaN
# 2021-07-01    70000.0
# NaT           75000.0
# NaT               NaN
# Name: Product Salescost, dtype: float64

# %%
data2.isnull().sum()
# Out:
# 155

# %%
data2.shape
# Out:
# (475,)

# %%
data2.describe()
# Out:
# count       320.000000
# mean      56567.187500
# std       38520.271318
# min        7000.000000
# 25%        8000.000000
# 50%       74000.000000
# 75%       92000.000000
# max      108000.000000
# Name: Product Salescost, dtype: float64

# %% [markdown]
# # 1. Checking Stationarity

# %%
data2.plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
X=data2.values
split=int(len(X)/2)
X1,X2=X[0:split],X[split:]
mean1, mean2=X1.mean(),X2.mean()
var1, var2= X1.var(),X2.var()
print('mean1=%f,mean2=%f'%(mean1,mean2))
print('var1=%f,var2=%f'%(var1,var2))
# Out:
# mean1=nan,mean2=nan
# var1=nan,var2=nan

# %%
X=data2.values
result=adfuller(X)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# /Users/dragonazad/Downloads/BmaProject/server/Project-ZBST.ipynb Cell 43' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/dragonazad/Downloads/BmaProject/server/Project-ZBST.ipynb#ch0000042?line=0'>1</a> X=data2.values
# ----> <a href='vscode-notebook-cell:/Users/dragonazad/Downloads/BmaProject/server/Project-ZBST.ipynb#ch0000042?line=1'>2</a> result=adfuller(X)
#       <a href='vscode-notebook-cell:/Users/dragonazad/Downloads/BmaProject/server/Project-ZBST.ipynb#ch0000042?line=2'>3</a> print('ADF Statistic: %f'%result[0])
#       <a href='vscode-notebook-cell:/Users/dragonazad/Downloads/BmaProject/server/Project-ZBST.ipynb#ch0000042?line=3'>4</a> print('p-value : %f'%result[1])
#
# ...

# %%
X=data2.values
X=np.log(X)
result=adfuller(X)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
plt.figure(figsize=(12,8))
plt.plot(X)

# %%
data2.head()

# %%
X=data2.values
X=np.sqrt(X)
result=adfuller(X)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
X=data2.values

# %%
X

# %%
diff=list()

# %%
diff

# %%
for i in range(1, len(X)):
    value = X[i] - X[i - 1]
    diff.append(value)

plt.figure(figsize=(20,6))
plt.plot(diff)
plt.show()

# %%
diff

# %%
result=adfuller(diff)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
diff2=list()
for i in range(1, len(diff)):
    value = diff[i] - diff[i - 1]
    diff2.append(value)

plt.figure(figsize=(20,6))
plt.plot(diff2)
plt.show()

# %%
result=adfuller(diff2)
print('ADF Statistic: %f'%result[0])
print('p-value : %f'%result[1])
print(' Citical Values:')
for key , value in result[4].items():
    print('\t%s: %.3f' % (key, value))

# %%
data2.head()

# %%
# Create lagged dataset
values = pd.DataFrame(data2.values)
dataframe = pd.concat([values.shift(1), values], axis=1)
dataframe.columns = ['t', 't+1']
print(dataframe.head(5))

# %%
# split into train and test sets
X = dataframe.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %%
len(test)

# %% [markdown]
# # Step 3 Persistence Algorithm
#
# We can define our persistence model as a function that returns the value provided as input. For example, if the t value of 266.0 was provided, then this is returned as the prediction, whereas the actual real or expected value happens to be 145.9 (taken from the frst usable row in our lagged dataset).

# %%
# persistence model
def model_persistence(x):
    return x

# %% [markdown]
# Make and Evaluate Forecast
#
# Now we can evaluate this model on the test dataset. We do this using the walk-forward validation method. No model training or retraining is required, so in essence, we step through the test dataset time step by time step and get predictions. Once predictions are made for each time step in the test dataset, they are compared to the expected values and a Root Mean Squared Error (RMSE) score is calculated.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller

# %%
# walk-forward validation
predictions = list()
for x in test_X:
    yhat = model_persistence(x)
    predictions.append(yhat)
rmse = np.sqrt(mean_squared_error(test_y, predictions))
print('Test RMSE: %.3f' % rmse)

# %%
# plot predictions vs expected
plt.figure(figsize=(10,6))
plt.plot(test_y)
plt.plot(predictions, color='red')
plt.show()

# %%
# plot predictions and expected results
plt.figure(figsize=(10,6))
plt.plot(train_y)
plt.plot([None for i in train_y] + [x for x in test_y],color='black')
plt.plot([None for i in train_y] + [x for x in predictions],color='yellow')
plt.show()

# %%
train_y

# %%
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
from math import sqrt
X = data2.values
train, test = X[1:len(X)-7], X[len(X)-7:]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test[i]))
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)

# %%
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
arr = {}
for x in range(1, 13):
    arr[x] = data[data['Month']==x]['Total Amount'].sum()

# %%
arr

# %%
max(arr.values())

# %% [markdown]
# # Product Prediction

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
y = np.array(list(arr.values()))

# %%
y

# %%
x = np.array(list(arr.keys())).reshape((-1, 1))

# %%
x

# %%
model.fit(x, y)

# %%
r_sq = model.score(x, y)
print(f"coefficient of determination: {r_sq}")

# %%
print(f"intercept: {model.intercept_}")


print(f"slope: {model.coef_}")

# %%
new_model = LinearRegression().fit(x, y.reshape((-1, 1)))
print(f"intercept: {new_model.intercept_}")


print(f"slope: {new_model.coef_}")

# %%
x

# %%
y_pred = model.predict(x)
print(f"predicted response:\n{y_pred}")

# %%
y_pred = model.intercept_ + model.coef_ * x
print(f"predicted response:\n{y_pred}")

# %%
x_new = np.arange(19).reshape((-1, 1))
x_new = x_new[13:]
x_new

# %%
sale_prediction = list(arr.values())
val = model.predict(x_new)
for z in val:
    sale_prediction.append(z)
sale_prediction

# %%
from sklearn.preprocessing import PolynomialFeatures
 
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(x)
 
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)

# %%
plt.scatter(x, y, color = 'blue')
 
plt.plot(x, model.predict(x), color = 'red')
plt.title('Linear Regression')
plt.xlabel('Months')
plt.ylabel('Sales')
 
plt.show()

# %%
plt.scatter(x, y, color = 'blue')
 
plt.plot(x, lin2.predict(poly.fit_transform(x)), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('Months')
plt.ylabel('Sales')
 
plt.show()

# %%
pred = 19
predarray = np.array([[pred]])
model.predict(predarray)

# %%
pred2 = 16
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))

# %% [markdown]
# # Sale Prediction

# %%
prdct_amt = len(data['Product Name'].unique())

# %%
product = data['Product Name'].unique()
product

# %%
prdct_amt

# %%
f = data[data['Product Name']=='Haier Single Door HDF-24']

# %%
f[f['Month']==1.0]

# %%
dictionary = {}

quant = []

for x_mon in range(12):
    for y_prd in range(12):
        f = data[data['Product Name']==product[x_mon]]
        f = f[f['Month']==y_prd+1]
        quant.append(f[f['Month']==y_prd+1]['Product Quantity'].sum())
    dictionary[product[x_mon]] = quant
    quant = []
print(dictionary)

# %%
data

# %%
dictionary['Samsung S-21']

# %%
x

# %%
model_p = LinearRegression()

# %%
model_p.fit(x, y)

# %%
x_new = np.arange(19).reshape((-1, 1))
x_new = x_new[13:]

print(x_new)

product_prediction = {}


for prod in product:
    model_p = LinearRegression()
    y = np.array(dictionary[prod])
    model_p.fit(x, y)
    r_sq = model_p.score(x, y)
    y_new = model_p.predict(x_new)
    product_prediction[prod] = dictionary[prod]
    for dist in y_new:
        product_prediction[prod].append(dist)

# %%
product_prediction

# %% [markdown]
# # Flask

# %%
from flask import Flask

# %%
__name__ = "hello"
app = Flask(__name__)

# %%
@app.route("/product_prediction", methods=['GET'])
def product_predict():
    return str({
        "dat": product_prediction
    })

# %%
@app.route("/sale_prediction", methods=['GET'])
def sale_predict():
    return str({
        "dat": sale_prediction
    })

# %%
app.run(debug=False,port=5000)
